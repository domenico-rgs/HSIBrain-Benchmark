# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

# %% [markdown]
# ## N. Parameters

# %%
helicoid = {
    'HiT': (44960609, 88.29),
    'DBDA': (249567, 90.51),
    'GhostNet': (46386, 84.22),
    'Hyb3D2D': (9696612, 91.13),
    'LiteDwNet': (35212, 84.73),
    'RSSAN': (79013, 90.33),
    'SSAN': (4302436, 89.05),
    'SpectralFormer': (201141, 87.57),
    'ViT': (211844, 75.81),
    'EfficientNet': (52890480, 89.72)
}

slimbrain = {
    'HiT': (1441569, 58.86),
    'ViT': (205252, 52.00),
    'DBDA': (59895, 61.83),
    'GhostNet': (31554, 56.69),
    'Hyb3D2D': (2102628, 63.7),
    'LiteDwNet': (13180, 10.80),
    'RSSAN': (45287, 57.61),
    'SSAN': (1550276, 60.82),
    'SpectralFormer': (98450, 60.37),
    'EfficientNet': (52868232, 37.31)
}

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sc_lp = ax.scatter(
    [x for x, y in helicoid.values()],
    [y for x, y in helicoid.values()],
    color='blue', marker='^', label='HELICoiD'
)

sc_m = ax.scatter(
    [x for x, y in slimbrain.values()],
    [y for x, y in slimbrain.values()],
    color='red', marker='s', label='SLIMBRAIN'
)

texts = []
for model, (x, y) in helicoid.items():
    texts.append(ax.text(x, y, model, fontsize=9))
for model, (x, y) in slimbrain.items():
    texts.append(ax.text(x, y, model, fontsize=9))

adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray', lw=0.5))

ax.set_xlabel("Number of parameters")
ax.set_ylabel("Average F1-score (%)")
ax.set_ylim(10, 95)
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.legend(loc='lower right')


plt.savefig("scatter_plot_parameters.png", dpi=1200, bbox_inches='tight', transparent=True)
plt.show()

# %% [markdown]
# ## Time

# %%
helicoid = {
    'HiT': (30.09, 88.29),
    'DBDA': (35.95, 90.51),
    'GhostNet': (17.89, 84.22),
    'Hyb3D2D': (35.98, 91.13),
    'LiteDwNet': (28.34, 84.73),
    'RSSAN': (17.99, 90.33),
    'SSAN': (41.43, 89.05),
    'SpectralFormer': (26.44, 87.57),
    'ViT': (51.03, 75.81),
    'EfficientNet': (25.53, 89.72)
}

slimbrain = {
    'HiT': (31.58, 58.86),
    'ViT': (10.46, 52.00),
    'DBDA': (10.17, 61.83),
    'GhostNet': (8.05, 56.69),
    'Hyb3D2D': (10.15, 63.7),
    'LiteDwNet': (9.18, 10.80),
    'RSSAN': (8.36, 57.61),
    'SSAN': (11.29, 60.82),
    'SpectralFormer': (8.86, 60.37),
    'EfficientNet': (39.20, 37.31)
}

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sc_lp = ax.scatter(
    [x for x, y in helicoid.values()],
    [y for x, y in helicoid.values()],
    color='blue', marker='^', label='HELICoiD'
)

sc_m = ax.scatter(
    [x for x, y in slimbrain.values()],
    [y for x, y in slimbrain.values()],
    color='red', marker='s', label='SLIMBRAIN'
)

texts = []
for model, (x, y) in helicoid.items():
    texts.append(ax.text(x, y, model, fontsize=9))
for model, (x, y) in slimbrain.items():
    texts.append(ax.text(x, y, model, fontsize=9))

adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray', lw=0.5))

ax.set_xlabel("Inference Time per Pixel (µs)")
ax.set_ylabel("Average F1-score (%)")
ax.set_ylim(10, 95)
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.legend(loc='lower right')

plt.savefig("scatter_plot_time.png", dpi=1200, bbox_inches='tight', transparent=True)
plt.show()
